# %% [markdown]
# <a href="https://colab.research.google.com/github/allaboutsimple/aibootcamp/blob/main/N112.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
myfiles=files.upload()
# Out:
#      <input type="file" id="files-f6d80072-5293-448b-b02e-ace75342fe73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6d80072-5293-448b-b02e-ace75342fe73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Travel.csv to Travel (2).csv

# %%
import pandas as  pd
import io

df = pd.read_csv(io.BytesIO(myfiles['Travel.csv']))
print(df)
# Out:
#         주요재무정보 2019/09\n(IFRS연결)  ... 2021/03(E)\n(IFRS연결) 2021/06(E)\n(IFRS연결)
# 0          매출액            14,753  ...                9,761                9,820
# 1         영업이익               574  ...                  144                  265
# 2   영업이익(발표기준)               574  ...                  NaN                  NaN
# 3     세전계속사업이익               376  ...                   14                  172
# 4        당기순이익               274  ...                   71                  214
# 5    당기순이익(지배)               277  ...                   53                  123
# 6   당기순이익(비지배)                -3  ...                  NaN                  NaN
# 7         자산총계            37,747  ...                  NaN                  NaN
# 8         부채총계            28,854  ...                  NaN                  NaN
# 9         자본총계             8,893  ...                  NaN                  NaN
# 10    자본총계(지배)             8,889  ...                  NaN                  NaN
# ...

# %%
column_headers = ['매출액','영업이익','영업이익(발표기준)','세전계속사업이익','당기순이익','당기순이익(지배)','당기순이익(비지배)','자산총계','부채총계','자본총계','자본총계(지배)','자본총계(비지배)','자본금']
df = pd.read_csv(io.BytesIO(myfiles['Travel.csv']), names = column_headers)
print(df.head())
print(df.shape)
# Out:
#           매출액               영업이익         영업이익(발표기준)  ... 자본총계(지배) 자본총계(비지배) 자본금
# 0      주요재무정보  2019/09\n(IFRS연결)  2019/12\n(IFRS연결)  ...      NaN       NaN NaN
# 1         매출액             14,753             15,440  ...      NaN       NaN NaN
# 2        영업이익                574                776  ...      NaN       NaN NaN
# 3  영업이익(발표기준)                574                776  ...      NaN       NaN NaN
# 4    세전계속사업이익                376                538  ...      NaN       NaN NaN
#
# [5 rows x 13 columns]
# (33, 13)

# %%
df=df.transpose()
df
# Out:
#                           1     2           3   ...        30       31         32
# 0                                               ...
# 주요재무정보                   매출액  영업이익  영업이익(발표기준)  ...  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)     14,753   574         574  ...         0      NaN          0
# 2019/12\n(IFRS연결)     15,440   776         776  ...       350      NaN      34.94
# 2020/03\n(IFRS연결)      9,437  -668        -668  ...       NaN      NaN          0
# 2020/06\n(IFRS연결)      5,230  -634        -634  ...       NaN      NaN          0
# 2020/09\n(IFRS연결)      8,795  -198        -198  ...       NaN      NaN        NaN
# 2020/12(E)\n(IFRS연결)   9,980    50         NaN  ...       NaN      NaN        NaN
# 2021/03(E)\n(IFRS연결)   9,761   144         NaN  ...       NaN      NaN        NaN
# 2021/06(E)\n(IFRS연결)   9,820   265         NaN  ...       NaN      NaN        NaN
# NaN                      NaN   NaN         NaN  ...       NaN      NaN        NaN
# ...

# %%
df.rename(columns=df.iloc[0],inplace=True)
df = df.drop(df.index[0])
df
# Out:
#                          매출액  영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 0                                              ...
# 2019/09\n(IFRS연결)     14,753   574        574  ...        0     NaN         0
# 2019/12\n(IFRS연결)     15,440   776        776  ...      350     NaN     34.94
# 2020/03\n(IFRS연결)      9,437  -668       -668  ...      NaN     NaN         0
# 2020/06\n(IFRS연결)      5,230  -634       -634  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)      8,795  -198       -198  ...      NaN     NaN       NaN
# 2020/12(E)\n(IFRS연결)   9,980    50        NaN  ...      NaN     NaN       NaN
# 2021/03(E)\n(IFRS연결)   9,761   144        NaN  ...      NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)   9,820   265        NaN  ...      NaN     NaN       NaN
# NaN                      NaN   NaN        NaN  ...      NaN     NaN       NaN
# NaN                      NaN   NaN        NaN  ...      NaN     NaN       NaN
# ...

# %%
df.shape
# Out:
# (12, 32)

# %%
df.fillna(0)
# Out:
#                          매출액  영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 0                                              ...
# 2019/09\n(IFRS연결)     14,753   574        574  ...        0       0         0
# 2019/12\n(IFRS연결)     15,440   776        776  ...      350       0     34.94
# 2020/03\n(IFRS연결)      9,437  -668       -668  ...        0       0         0
# 2020/06\n(IFRS연결)      5,230  -634       -634  ...        0       0         0
# 2020/09\n(IFRS연결)      8,795  -198       -198  ...        0       0         0
# 2020/12(E)\n(IFRS연결)   9,980    50          0  ...        0       0         0
# 2021/03(E)\n(IFRS연결)   9,761   144          0  ...        0       0         0
# 2021/06(E)\n(IFRS연결)   9,820   265          0  ...        0       0         0
# NaN                        0     0          0  ...        0       0         0
# NaN                        0     0          0  ...        0       0         0
# ...

# %%
df.fcf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-a06a9e55e293> in <module>()
# ----> 1 df.fcf
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'fcf'

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import numpy as np
label = np.array(FCF)
print(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-e26b39b79730> in <module>()
#       1 import numpy as np
# ----> 2 label = np.array(FCF)
#       3 print(label)
#
# NameError: name 'FCF' is not defined
