# %% [markdown]
# <a href="https://colab.research.google.com/github/allaboutsimple/aibootcamp/blob/main/n111a_eda_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 1*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# ## 1.데이터셋 불러오기 연습
#
# 다음 url에서 엑셀 파일을 불러오세요. (pandas excel)
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx>
#
#   - 데이터셋 변수의 이름은 `df1`, `df2`로 저장하세요.
#   - row가 아닌 column에 '매출액', '영업이익' 이 가도록 데이터를 transpose 하세요.
#   - 이후 아래 링크를 참조하여 첫번째 row를 column name으로 설정하세요.
#
# <https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row>
#
# - 파일은 2개의 시트로 구성되어 있으며 각각 이름은 `008770`, `035250` 입니다.

# %%
'''업로드하는 방식 차이
from google.colab import files
uploaded = files.upload()

df1 = pd.read_excel('Travel.xlsx', sheet_name='008770 ')
print(df1)
'''
# Out:
# "업로드하는 방식 차이\nfrom google.colab import files\nuploaded = files.upload()\n\ndf1 = pd.read_excel('Travel.xlsx', sheet_name='008770 ')\nprint(df1)\n"

# %%
travel = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx'

# %%
import numpy as pd
import pandas as pd
df = pd.read_excel(travel)
df.head()
# Out:
#        주요재무정보  2019/09\n(IFRS연결)  ...  2021/03(E)\n(IFRS연결)  2021/06(E)\n(IFRS연결)
# 0         매출액            14753.0  ...                9761.0                9820.0
# 1        영업이익              574.0  ...                 144.0                 265.0
# 2  영업이익(발표기준)              574.0  ...                   NaN                   NaN
# 3    세전계속사업이익              376.0  ...                  14.0                 172.0
# 4       당기순이익              274.0  ...                  71.0                 214.0
#
# [5 rows x 9 columns]

# %%
#시트 두개 나누어서 불러오기

df1 = pd.read_excel(travel, sheet_name= 0 )
df2 = pd.read_excel(travel, sheet_name= 1 )
df1.head()
# Out:
#        주요재무정보  2019/09\n(IFRS연결)  ...  2021/03(E)\n(IFRS연결)  2021/06(E)\n(IFRS연결)
# 0         매출액            14753.0  ...                9761.0                9820.0
# 1        영업이익              574.0  ...                 144.0                 265.0
# 2  영업이익(발표기준)              574.0  ...                   NaN                   NaN
# 3    세전계속사업이익              376.0  ...                  14.0                 172.0
# 4       당기순이익              274.0  ...                  71.0                 214.0
#
# [5 rows x 9 columns]

# %%
#행/열 위치 변경
df1=df1.transpose()
df2=df2.transpose()
df1
# Out:
#                          0     1           2   ...        29       30         31
# 주요재무정보                  매출액  영업이익  영업이익(발표기준)  ...  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)     14753   574         574  ...         0      NaN          0
# 2019/12\n(IFRS연결)     15440   776         776  ...       350      NaN      34.94
# 2020/03\n(IFRS연결)      9437  -668        -668  ...       NaN      NaN          0
# 2020/06\n(IFRS연결)      5230  -634        -634  ...       NaN      NaN          0
# 2020/09\n(IFRS연결)      8795  -198        -198  ...       NaN      NaN        NaN
# 2020/12(E)\n(IFRS연결)   9980    50         NaN  ...       NaN      NaN        NaN
# 2021/03(E)\n(IFRS연결)   9761   144         NaN  ...       NaN      NaN        NaN
# 2021/06(E)\n(IFRS연결)   9820   265         NaN  ...       NaN      NaN        NaN
#
# [9 rows x 32 columns]

# %%
#행에서 열 첫번째줄로 옮겨진 인덱스 제거
df1.rename(columns=df1.iloc[0],inplace=True)
df1 = df1.drop(df1.index[0])
df1
# Out:
#                         매출액 영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)     14753  574        574  ...        0     NaN         0
# 2019/12\n(IFRS연결)     15440  776        776  ...      350     NaN     34.94
# 2020/03\n(IFRS연결)      9437 -668       -668  ...      NaN     NaN         0
# 2020/06\n(IFRS연결)      5230 -634       -634  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)      8795 -198       -198  ...      NaN     NaN       NaN
# 2020/12(E)\n(IFRS연결)   9980   50        NaN  ...      NaN     NaN       NaN
# 2021/03(E)\n(IFRS연결)   9761  144        NaN  ...      NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)   9820  265        NaN  ...      NaN     NaN       NaN
#
# [8 rows x 32 columns]

# %%
df2.rename(columns=df2.iloc[0],inplace=True)
df2 = df2.drop(df2.index[0])
df2
# Out:
#                        매출액  영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)     4055  1392       1392  ...        0     NaN         0
# 2019/12\n(IFRS연결)     3728   641        641  ...      900     NaN    346.75
# 2020/03\n(IFRS연결)     2360 -1868      -1868  ...      NaN     NaN       NaN
# 2020/06\n(IFRS연결)      346 -1038      -1038  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)      766  -649       -649  ...      NaN     NaN       NaN
# 2020/12(E)\n(IFRS연결)  1581  -434        NaN  ...      NaN     NaN       NaN
# 2021/03(E)\n(IFRS연결)  1473  -187        NaN  ...      NaN     NaN       NaN
# 2021/06(E)\n(IFRS연결)  1746   -65        NaN  ...      NaN     NaN       NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# ## 2. 데이터 확인
#
# - 데이터의 dimension을 확인하세요.
# - 데이터의 결측치가 어디에 있는지 확인 후 0으로 대체하세요.
# - 각 데이터 별로 **FCF**의 값을 barplot으로 시각화하세요.
#   - 0보다 큰값, 작은값의 수의 총합을 `num1`, `num2`에 저장하세요

# %%
df1.shape
# Out:
# (8, 32)

# %%
df2.shape
# Out:
# (8, 32)

# %%
#isnull로 값이 없는 부분 확인
df1.isnull().sum()
df2.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    3
# 세전계속사업이익      2
# 당기순이익         2
# 당기순이익(지배)     0
# 당기순이익(비지배)    3
# 자산총계          2
# 부채총계          2
# 자본총계          2
# 자본총계(지배)      2
# 자본총계(비지배)     6
# 자본금           2
# 영업활동현금흐름      3
# 투자활동현금흐름      3
# 재무활동현금흐름      3
# CAPEX         3
# FCF           3
# 이자발생부채        3
# 영업이익률         0
# 순이익률          2
# ROE(%)        3
# ROA(%)        3
# 부채비율          2
# 자본유보율         3
# EPS(원)        0
# PER(배)        5
# BPS(원)        2
# PBR(배)        2
# 현금DPS(원)      6
# 현금배당수익률       8
# 현금배당성향(%)     5
# dtype: int64

# %%
df1.fillna(0)
df2.fillna(0)
# Out:
#                          매출액    영업이익  영업이익(발표기준)  ...  현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)     4055.0  1392.0      1392.0  ...       0.0        0       0.00
# 2019/12\n(IFRS연결)     3728.0   641.0       641.0  ...     900.0        0     346.75
# 2020/03\n(IFRS연결)     2360.0 -1868.0     -1868.0  ...       0.0        0       0.00
# 2020/06\n(IFRS연결)      346.0 -1038.0     -1038.0  ...       0.0        0       0.00
# 2020/09\n(IFRS연결)      766.0  -649.0      -649.0  ...       0.0        0       0.00
# 2020/12(E)\n(IFRS연결)  1581.0  -434.0         0.0  ...       0.0        0       0.00
# 2021/03(E)\n(IFRS연결)  1473.0  -187.0         0.0  ...       0.0        0       0.00
# 2021/06(E)\n(IFRS연결)  1746.0   -65.0         0.0  ...       0.0        0       0.00
#
# [8 rows x 32 columns]

# %%
a=df1['FCF']
b=df2['FCF']

# %%
##글씨체 선명하게 프린트하는 방법 고민해보기
a.plot.bar()
b.plot.bar()
# Out:
# findfont: Font family ['nanummyeongjo'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df1['FCF']
# Out:
# 2019/09\n(IFRS연결)       1493
# 2019/12\n(IFRS연결)       -589
# 2020/03\n(IFRS연결)      -4680
# 2020/06\n(IFRS연결)        789
# 2020/09\n(IFRS연결)       2975
# 2020/12(E)\n(IFRS연결)     NaN
# 2021/03(E)\n(IFRS연결)     NaN
# 2021/06(E)\n(IFRS연결)     NaN
# Name: FCF, dtype: object

# %%
df2['FCF']
# Out:
# 2019/09\n(IFRS연결)       -189
# 2019/12\n(IFRS연결)       1684
# 2020/03\n(IFRS연결)       -808
# 2020/06\n(IFRS연결)      -3153
# 2020/09\n(IFRS연결)      -1844
# 2020/12(E)\n(IFRS연결)     NaN
# 2021/03(E)\n(IFRS연결)     NaN
# 2021/06(E)\n(IFRS연결)     NaN
# Name: FCF, dtype: object

# %%
#공식으로 값구하는법 연구하기#

num1=1493+789+2975+1684
num2=-589-4680-189-808-3153-1844
num1
# Out:
# 6941

# %%
   
num2
# Out:
# -11263

# %% [markdown]
# ## 3. File export
#
# - 읽었던 엑셀 파일의 내용을 2개의 csv로 각각 출력하세요. (python export csv)
#
#   - 이름은 각각 `df1.csv`, `df2.csv` 입니다.

# %%
df1.to_csv ("df1.csv")
df2.to_csv ("df2.csv")

# %% [markdown]
# ## 4. Error Handling
#
# - 다음의 에러를 고치세요. 결과값은 6912가 나와야합니다.

# %%
a = 1234
b = 5678

a+b
# Out:
# 6912

# %% [markdown]
# 5. EDA
# 아래의 코드는 palmer penguin 데이터를 불러올 수 있는 코드입니다.
#
# import seaborn as sns
#
# pp = sns.load_dataset('penguins')
# 이를 참조하여, pp의 species와 sex변수에 대해서 cross-tabulation을 시행하고, 6개의 값들 중 가장 큰 값을 num3에, 가장 작은 값을 num4에 저장하세요.
# ```

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pp = sns.load_dataset('penguins')

# %%
table = pd.crosstab(pp.species, pp.sex)
print(table)
# Out:
# sex        Female  Male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %%
sns.countplot(x="species", hue="sex", data=pp)
plt.show()

# %%
num3=73
num4=34

# %% [markdown]
# ## Grading
#
# 이전 과제를 완료했다면, 아래의 코드를 실행하세요.

# %%
import os

def grade(df1, df2, num1, num2, num3, num4):
  score = 0
  
  score += (df1['매출액'][0] == 14753)
  score += (df2['매출액'][1] == 3728)

  score += (df1.shape == (7, 32))
  score += (df2.isnull().sum().sum() == 0)
  score += (num1 == 4 and num2 == 6)
  
  score += (num3 == 73 and num4 == 34)

  score += (os.listdir() == ['.config', 'df2.csv', 'df1.csv', 'sample_data'])

  score += (a+b == 6912)

  return(score)
# Out:
#   File "<ipython-input-63-43d03824a04b>", line 9
#     score += (df1.shape == (7, 32))
#     ^
# IndentationError: unexpected indent

# %%
num1 == 4 and num2 == 6
# Out:
# False

# %%
grade(df1, df2, num1, num2, num3, num4)
# Out:
# 4

# %% [markdown]
# ## 🔥 도전과제
#
# - 다음 데이터를 사용하여 아래와 동일한 그래프를 그리세요.
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/TSLA.csv>
#
# <img src='https://i.imgur.com/UsS5JcZ.png'>

# %% [markdown]
# - penguins 데이터를 계속 사용합니다.
#
# 이에 대해 아래의 task들을 시행하세요.
#
# - 결측치 처리 (제거)
#
# - bill_length_mm에 대해서 qqplot 그리기
#
# - island에 대해서 다른 4개의 numerical feature 를 boxplot으로 표현하기
#
# - 각 numerical feature에 대해서 summary statistics : mean, sd, Quantiles(1Q, 2Q, 3Q, 4Q)를 계산하세요.
